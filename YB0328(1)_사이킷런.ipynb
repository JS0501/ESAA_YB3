# %% [markdown]
# <a href="https://colab.research.google.com/github/JS0501/ESAA_YB3/blob/main/YB0328(1)_%EC%82%AC%EC%9D%B4%ED%82%B7%EB%9F%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## 데이터 다운로드
# ---
# 아래 셀을 실행시켜 데이터를 colab에 불러옵니다.
# 셀 실행은 Ctrl + Enter 를 이용해 실행시킬 수 있습니다.

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3gLj0Q6'

import zipfile
with zipfile.ZipFile('3gLj0Q6', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# --2025-03-28 10:40:55--  https://bit.ly/3gLj0Q6
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E [following]
# --2025-03-28 10:40:55--  https://drive.google.com/uc?export=download&id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E
# Resolving drive.google.com (drive.google.com)... 74.125.134.113, 74.125.134.139, 74.125.134.138, ...
# Connecting to drive.google.com (drive.google.com)|74.125.134.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E&export=download [following]
# --2025-03-28 10:40:55--  https://drive.usercontent.google.com/download?id=1or_QN1ksv81DNog6Tu_kWcZ5jJWf5W9E&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39208 (38K) [application/octet-stream]
# Saving to: ‘3gLj0Q6.2’
#
# 3gLj0Q6.2           100%[===================>]  38.29K  --.-KB/s    in 0.001s
#
# 2025-03-28 10:40:57 (73.4 MB/s) - ‘3gLj0Q6.2’ saved [39208/39208]

# %% [markdown]
# ## 라이브러리 불러오기
# ---
# 아래 셀을 실행시켜 pandas 와 DecisionTreeRegressor 를 불러옵니다.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## 데이터 불러오기
# ---
# 아래 셀을 실행시켜 csv 파일 데이터를 DataFrame 객체로 불러옵니다.

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %% [markdown]
# ## 결측치 제거하기
# ---
# 결측치를 제거하고, 결측치가 모두 제거됐는지 확인합니다.

# %%
test = test.dropna()
train = train.dropna()

print(train.isnull().sum())
# Out:
# id                        0
# hour                      0
# hour_bef_temperature      0
# hour_bef_precipitation    0
# hour_bef_windspeed        0
# hour_bef_humidity         0
# hour_bef_visibility       0
# hour_bef_ozone            0
# hour_bef_pm10             0
# hour_bef_pm2.5            0
# count                     0
# dtype: int64

# %% [markdown]
# 1. train 데이터중 <br>
# (1) 예측해야할 `count` 피쳐를 drop()함수를 사용하고, axis=1 옵션을 사용해 해당 열을 제외한 데이터들을 `X_train` 이라는 이름의 DataFrame 객체로 만들고 <br>
# (2) `count` 피쳐만을 데이터로 갖는 `Y_train` 이라는 이름의 DataFrame 객체로 만드는 코드를 아래에 작성하세요

# %%
X_train = train.drop('count', axis=1)
Y_train = train[['count']]

# %% [markdown]
# 2. `model` 변수명으로 모델을 선언하고, fit() 함수를 사용해서, `X_train` 을 input 으로 삼고, `Y_train` 을 output 으로 삼아 모델을 훈련시키는 코드를 아래에 작성하세요

# %%
model = DecisionTreeRegressor()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# 3. predict() 를 이용해 test data 를 훈련된 모델로 예측한 data 를 생성하고 예측결과 상위 5개를 출력하는 코드를 작성하세요.

# %%
y_pred = model.predict(test)
top_5_predictions = y_pred[:5]
print(top_5_predictions)
# Out:
# [106. 164.  88.  49.  64.]

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## 데이터 다운로드
# ---
# 아래 셀을 실행시켜 데이터를 colab 에 불러옵니다.
# 셀 실행은 Ctrl + Enter 를 이용해 실행시킬 수 있습니다.

# %%
# 데이터 다운로드 링크로 데이터를 코랩에 불러옵니다.

# !wget 'https://bit.ly/3i4n1QB'

import zipfile
with zipfile.ZipFile('3i4n1QB', 'r') as existing_zip:
    existing_zip.extractall('data')
# Out:
# --2025-03-28 10:41:08--  https://bit.ly/3i4n1QB
# Resolving bit.ly (bit.ly)... 67.199.248.11, 67.199.248.10
# Connecting to bit.ly (bit.ly)|67.199.248.11|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://drive.google.com/uc?export=download&id=1emLrrpFWT8dCoj5BJb12-5QMG2-nruUw [following]
# --2025-03-28 10:41:09--  https://drive.google.com/uc?export=download&id=1emLrrpFWT8dCoj5BJb12-5QMG2-nruUw
# Resolving drive.google.com (drive.google.com)... 74.125.134.113, 74.125.134.139, 74.125.134.138, ...
# Connecting to drive.google.com (drive.google.com)|74.125.134.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1emLrrpFWT8dCoj5BJb12-5QMG2-nruUw&export=download [following]
# --2025-03-28 10:41:09--  https://drive.usercontent.google.com/download?id=1emLrrpFWT8dCoj5BJb12-5QMG2-nruUw&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.134.132, 2607:f8b0:400c:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.134.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137694 (134K) [application/octet-stream]
# Saving to: ‘3i4n1QB.1’
#
# 3i4n1QB.1           100%[===================>] 134.47K  --.-KB/s    in 0.001s
#
# 2025-03-28 10:41:11 (105 MB/s) - ‘3i4n1QB.1’ saved [137694/137694]

# %%
# 라이브러리 불러오기

import pandas as pd
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv('data/train.csv')

# Scailing
scaler = MinMaxScaler()
scaler.fit(train[['fixed acidity']])
train['Scaled fixed acidity'] = scaler.transform(train[['fixed acidity']])

# Encoding
encoder = OneHotEncoder()
encoder.fit(train[['type']])
onehot = encoder.transform(train[['type']])
onehot = onehot.toarray()
onehot = pd.DataFrame(onehot)
onehot.columns = encoder.get_feature_names_out()
train = pd.concat([train, onehot], axis = 1)
train = train.drop(columns = ['type'])
train.head()
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol  Scaled fixed acidity  type_red  \
# 0  0.99432  3.44       0.44     10.2              0.148760       0.0
# 1  0.99690  3.19       0.59      9.5              0.413223       1.0
# 2  0.99176  3.05       0.52     10.9              0.338843       0.0
# 3  0.99390  3.26       0.50     10.8              0.264463       0.0
# 4  0.99550  3.04       0.43     10.9              0.330579       0.0
#
#    type_white
# 0         1.0
# 1         0.0
# 2         1.0
# 3         1.0
# 4         1.0

# %% [markdown]
# 4. sklearn에 model_selection 모듈에서 KFold를 불러와보세요

# %%
from sklearn.model_selection import KFold

# %% [markdown]
# 5. KFold에 n_splits = 5, shuffle = True, random_state = 0이라는 인자를 추가해 "kf"라는 변수에 저장해보세요

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# 6. 반복문을 통해서 1번부터 5번까지의 데이터에 접근해보세요

# %%
for fold_number, (train_index, test_index) in enumerate(kf.split(X_train), 1):
    print(f"Fold {fold_number}:")
    print(f"Train indices: {train_index}, Test indices: {test_index}")

    # 각 폴드에 해당하는 훈련 데이터와 테스트 데이터 추출
    X_train_fold, X_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    Y_train_fold, Y_test_fold = Y_train.iloc[train_index], Y_train.iloc[test_index]

    # 훈련 데이터와 테스트 데이터 출력
    print(f"X_train_fold: {X_train_fold.values.flatten()}")
    print(f"Y_train_fold: {Y_train_fold.values.flatten()}")
    print(f"X_test_fold: {X_test_fold.values.flatten()}")
    print(f"Y_test_fold: {Y_test_fold.values.flatten()}")
    print("-" * 50)
# Out:
# Fold 1:
# Train indices: [   0    2    3 ... 1325 1326 1327], Test indices: [   1    5    8    9   14   18   27   31   34   39   45   47   52   53
#    54   55   58   61   75   80   85   92  108  124  140  141  142  152
#   156  159  161  184  186  192  194  198  202  204  211  215  224  227
#   231  233  240  241  247  251  253  254  268  270  295  298  299  303
#   308  312  315  317  319  320  322  326  328  333  342  364  381  390
#   393  399  402  406  412  420  425  426  427  431  434  435  436  438
#   440  442  443  445  446  452  458  461  464  466  472  474  477  481
#   486  491  494  500  503  505  506  511  512  517  520  526  528  529
#   530  533  535  539  540  548  549  557  563  565  568  569  571  583
#   587  613  615  618  632  638  641  644  646  649  654  656  667  669
#   672  682  686  688  692  712  716  742  744  747  748  752  753  760
#   773  784  785  787  789  790  793  795  798  799  811  813  815  824
#   831  833  840  857  870  871  877  880  898  900  901  905  915  938
#   939  950  957  959  961  975  979  982  984  986  989  991  993  995
